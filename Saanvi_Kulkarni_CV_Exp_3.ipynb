# %% [markdown]
# **CV Exp - 3**
#
# **Texture feature extractions using GLCM**

# %% [markdown]
# Name: Saanvi Kulkarni
#
# PRN No.: 1032210698
#
# Division: A1
#
# Batch: A4

# %%
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage import data
from skimage.feature import greycomatrix,greycoprops

# %% [markdown]
# **Texture Images**

# %%
img1=cv2.imread('/content/smoothtexture.jpg')
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
img1 = cv2.resize(img1,(300,300),interpolation=cv2.INTER_LINEAR)
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=L size=300x300>

# %%
img2=cv2.imread('/content/coarsetexture.webp')
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
img2 = cv2.resize(img2,(300,300),interpolation=cv2.INTER_LINEAR)
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=L size=300x300>

# %%
img3=cv2.imread('/content/pebblestexture.jpg')
img3 = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)
img3 = cv2.resize(img3,(300,300),interpolation=cv2.INTER_LINEAR)
cv2_imshow(img3)
# Out:
# <PIL.Image.Image image mode=L size=300x300>

# %% [markdown]
# **Gaussian Filter**

# %%
img1 = cv2.GaussianBlur(img1,(5,5),0)
img2 = cv2.GaussianBlur(img2,(5,5),0)
img3 = cv2.GaussianBlur(img3,(5,5),0)

# %%
# Calculate GLCM (Gray Level Co-occurrence Matrix) for each image
distances = [1]
angles = [0]
properties = ['contrast', 'energy', 'correlation', 'homogeneity']

def calculate_texture_features(image):
    glcm = greycomatrix(image, distances=distances, angles=angles, levels=256, symmetric=True, normed=True)
    texture_features = [greycoprops(glcm, prop).ravel()[0] for prop in properties]
    return texture_features


smooth_features = calculate_texture_features(img1)
coarse_features = calculate_texture_features(img2)
pebble_features = calculate_texture_features(img3)
# Out:
# /usr/local/lib/python3.10/dist-packages/skimage/feature/__init__.py:35: skimage_deprecation: Function ``greycomatrix`` is deprecated and will be removed in version 1.0. Use ``skimage.feature.graycomatrix`` instead.
#   removed_version='1.0')
# /usr/local/lib/python3.10/dist-packages/skimage/feature/__init__.py:42: skimage_deprecation: Function ``greycoprops`` is deprecated and will be removed in version 1.0. Use ``skimage.feature.graycoprops`` instead.
#   removed_version='1.0')
# /usr/local/lib/python3.10/dist-packages/skimage/feature/__init__.py:42: skimage_deprecation: Function ``greycoprops`` is deprecated and will be removed in version 1.0. Use ``skimage.feature.graycoprops`` instead.
#   removed_version='1.0')
# /usr/local/lib/python3.10/dist-packages/skimage/feature/__init__.py:42: skimage_deprecation: Function ``greycoprops`` is deprecated and will be removed in version 1.0. Use ``skimage.feature.graycoprops`` instead.
#   removed_version='1.0')
# ...

# %%
distances = [5]  # Define distances for GLCM
angles = [0]  # Define angles (directions) for GLCM

# %%
glcm_img1=greycomatrix(img1, distances, angles, levels=256, symmetric=True, normed=True)
glcm_img2=greycomatrix(img2, distances, angles, levels=256, symmetric=True, normed=True)
glcm_img3=greycomatrix(img3, distances, angles, levels=256, symmetric=True, normed=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/skimage/feature/__init__.py:35: skimage_deprecation: Function ``greycomatrix`` is deprecated and will be removed in version 1.0. Use ``skimage.feature.graycomatrix`` instead.
#   removed_version='1.0')
# /usr/local/lib/python3.10/dist-packages/skimage/feature/__init__.py:35: skimage_deprecation: Function ``greycomatrix`` is deprecated and will be removed in version 1.0. Use ``skimage.feature.graycomatrix`` instead.
#   removed_version='1.0')
# /usr/local/lib/python3.10/dist-packages/skimage/feature/__init__.py:35: skimage_deprecation: Function ``greycomatrix`` is deprecated and will be removed in version 1.0. Use ``skimage.feature.graycomatrix`` instead.
#   removed_version='1.0')

# %%
plt.figure(figsize=(20, 16))

plt.subplot(1, 6, 1)
plt.imshow(img1)

plt.subplot(1, 6, 2)
plt.imshow(img2)

plt.subplot(1, 6, 3)
plt.imshow(img3)

# %%
properties = ['contrast', 'dissimilarity', 'homogeneity','energy', 'correlation']
images =[glcm_img1,glcm_img2,glcm_img3]
for image in images:
  for prop in properties:
      glcm_properties = graycoprops(image, prop)
      print(prop,':',glcm_properties)
  print("\n")
# Out:
# contrast : [[196.97097175]]
# dissimilarity : [[7.28864407]]
# homogeneity : [[0.26276627]]
# energy : [[0.02183932]]
# correlation : [[0.97174352]]
#
#
# contrast : [[1147.38237288]]
# dissimilarity : [[25.74076836]]
# homogeneity : [[0.04441782]]
# energy : [[0.00932741]]
# correlation : [[0.55781597]]
#
#
# contrast : [[2400.19073446]]
# dissimilarity : [[38.98318644]]
# homogeneity : [[0.02709561]]
# energy : [[0.00784115]]
# correlation : [[0.14442184]]

# %%
# Create a scatter plot for each GLCM property
for prop in properties:
    # Create a list to store property values for each image
    prop_values = []
    # Iterate over each image
    for image in images:
        # Compute GLCM properties for the current image
        glcm_properties = greycoprops(image, prop)
        # Append the property value to the list
        prop_values.append(glcm_properties)
    # Create a scatter plot for the current property
    plt.figure(figsize=(4, 4))
    plt.scatter(range(1, len(images) + 1), prop_values)
    plt.xlabel('Image Index')
    plt.ylabel(prop.capitalize())  # Use property name as y-axis label
    plt.title(f'Comparison of {prop.capitalize()} Across Images')
    plt.xticks(range(1, len(images) + 1))
    plt.grid(True)
    plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/skimage/feature/__init__.py:42: skimage_deprecation: Function ``greycoprops`` is deprecated and will be removed in version 1.0. Use ``skimage.feature.graycoprops`` instead.
#   removed_version='1.0')
# /usr/local/lib/python3.10/dist-packages/skimage/feature/__init__.py:42: skimage_deprecation: Function ``greycoprops`` is deprecated and will be removed in version 1.0. Use ``skimage.feature.graycoprops`` instead.
#   removed_version='1.0')
# /usr/local/lib/python3.10/dist-packages/skimage/feature/__init__.py:42: skimage_deprecation: Function ``greycoprops`` is deprecated and will be removed in version 1.0. Use ``skimage.feature.graycoprops`` instead.
#   removed_version='1.0')
# /usr/local/lib/python3.10/dist-packages/skimage/feature/__init__.py:42: skimage_deprecation: Function ``greycoprops`` is deprecated and will be removed in version 1.0. Use ``skimage.feature.graycoprops`` instead.
#   removed_version='1.0')
# ...
